# %%
import pandas as pd
import numpy as np

data=pd.read_csv("diabetes.csv")

dfs=pd.DataFrame(data)
# print (dfs.to_string())

# dfs.fillna(0,inplace=True)

col_1=dfs["Pregnancies"].mean()

col_len=len(dfs.columns)


for i in range(col_len):
    col_name=dfs.columns[i]
    avg=round(dfs[col_name].mean(),2)
    dfs[col_name].fillna(avg,inplace=True)
        


#print (dfs.columns[0])
print (dfs.head(5))

new_dfs=dfs[["Outcome","Insulin","Age","BMI","BloodPressure","Glucose"]]


# print (new_dfs.corr())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0          35.00   155.55  33.6
# 1            1     85.0           66.0          29.00   155.55  26.6
# 2            8    183.0           64.0          29.15   155.55  23.3
# 3            1     89.0           66.0          23.00    94.00  28.1
# 4            0    137.0           40.0          35.00   168.00  43.1
#
#    DiabetesPedigree  Age  Outcome
# 0             0.627   50        1
# 1             0.351   31        0
# 2             0.672   32        1
# 3             0.167   21        0
# 4             2.288   33        1
#                 Outcome   Insulin       Age       BMI  BloodPressure   Glucose
# Outcome        1.000000  0.214411  0.238356  0.311923       0.166078  0.492928
# Insulin        0.214411  1.000000  0.136736  0.166585       0.072518  0.420157
# Age            0.238356  0.136736  1.000000  0.025518       0.324591  0.266533
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt



# Correlation heatmap
plt.figure(figsize=(5,4))
sns.heatmap(new_dfs.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Check Up Parameter")
plt.show()
